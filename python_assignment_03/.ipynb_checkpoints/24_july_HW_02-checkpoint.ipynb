# %%
# !pip install opencv.python
# Out:
# Collecting opencv.python
#   Using cached opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in c:\users\yug\anaconda3\lib\site-packages (from opencv.python) (2.3.5)
# Using cached opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl (44.0 MB)
# Installing collected packages: opencv.python
# Successfully installed opencv.python-5.0.0.93

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r"image.jpg")
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img.shape)
# Out:
# (675, 1200, 3)

# %%
cv2.imshow("photos",img)
cv2.waitKey(0)
# Out:
# -1

# %%
resized = cv2.resize(img, (300, 300))
cv2.imshow("Resized", resized)
cv2.waitKey(0)
# Out:
# -1

# %%
flipped = cv2.flip(img, 1)

cv2.imshow("Flipped Image", flipped)
cv2.waitKey(0)
cv2.destroyAllWindows()
